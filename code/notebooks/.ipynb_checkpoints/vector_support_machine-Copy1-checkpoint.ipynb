# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import statsmodels.api as sm

# %%
# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.feature_selection import RFE

# %%
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso

# %%
from sklearn.svm import LinearSVC

# %%
from sklearn.feature_selection import SelectFromModel

# %%
from sklearn import metrics

# %%
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.feature_selection import RFE

# %%
from sklearn.preprocessing import StandardScaler

# %%
import math

# %%
from sklearn import svm

# %%
from sklearn.metrics import r2_score

# %%
from sklearn import preprocessing
from sklearn import utils

# %%
df = pd.read_csv('../../data/extracted_features_round4_training.csv', header=0)

# %%
df = df.drop(columns='Unnamed: 0')

# %%
#df = df[['CV', 'TABSSIMPSPACY', 'TAWSSIMSPACY', 'TAKWDIST', 'TABSSIMBERT', 'AKWPWMEAN',
#       'TAWSSIMPSPACY', 'TKWAORATIO', 'TAKWSIMSPACY', 'TMIKWP', 'TABSSIMSPACY',
#       'TAFSSIMSPACY', 'TAMIKWWSSIMSPACY', 'TKWAOWRATIO', 'TAFSSD']]

# %%
scaler = StandardScaler()

# %%
X = df.drop(columns='CV')

# %%
X = pd.DataFrame(scaler.fit_transform(X),columns = X.columns,index = df.index)

# %%
float_labels = np.array(df['CV'])

# %%
lab_enc = preprocessing.LabelEncoder()
labels = lab_enc.fit_transform(float_labels)

# %%
df.columns
# Out:
# Index(['CV', 'TL', 'AL', 'TWC', 'AWC', 'TSC', 'ASC', 'TALRATIO', 'TAWCRATIO',
#        'TASCRATIO', 'TP', 'AP', 'TAPD', 'TAPMEAN', 'TS', 'AS', 'TASD',
#        'TASMEAN', 'TASCCRATIO', 'TASCCD', 'TKWC', 'AKWC', 'TAKWCRATIO',
#        'AMIKWP', 'TMIKWS', 'AMIKWS', 'AFSP', 'TAFSPMEAN', 'TAFSPD', 'AFSS',
#        'TAFSSMEAN', 'TAFSSD', 'TMIKWAORATIO', 'TKWAORATIO', 'TKWAOWRATIO',
#        'TKWPMEAN', 'AKWPMEAN', 'TAKWPMEAN', 'TAKWPD', 'TKWPWMEAN', 'AKWPWMEAN',
#        'TAKWPWMEAN', 'TAKWPWD', 'TAMIKWFP', 'TAMIKWDIST', 'TAKWDIST',
#        'TASIMSPACY', 'TABSSIMSPACY', 'TAWSSIMSPACY', 'TAASSIMSPACY',
#        'TAFSSIMSPACY', 'TABSSIMPSPACY', 'TAWSSIMPSPACY', 'TAGSSIMRATIOSPACY',
#        'TVC', 'AVC', 'TAVCD', 'TNC', 'ANC', 'TANCD', 'TABSSIMBERT',
#        'TAWSSIMBERT', 'TAASSIMSBERT', 'TAFSSIMBERT', 'TABSSIMPBERT',
#        'TAWSSIMPBERT', 'TAGSSIMRATIOBERT', 'TAMIKWASSIMSPACY',
#        'TAMIKWBSSIMSPACY', 'TAMIKWWSSIMSPACY', 'TMIKWP', 'TAMKWSSIMSPACY',
#        'TAMKWSP', 'TAMKWSPD', 'TAMKWSS', 'TAMKWSSD', 'TAMKWFP', 'TAKWSIMSPACY',
#        'TAKWSP', 'TAKWSPD', 'TAKWSS', 'TAKWSSD', 'TAGSSIMDISTSPACY', 'TSCC',
#        'ASCC', 'TKWCRATIO', 'AKWCRATIO', 'TAKWCRATIORATIO', 'TMIKWAO', 'TKWAO',
#        'TKWAOW', 'TVCRATIO', 'AVCRATIO', 'TAVCRATIOD', 'TNCRATIO', 'ANCRATIO',
#        'TANCRATIOD', 'TAGSSIMCSPACY', 'TAGSSIMCBERT', 'TAKWSSIMVARSPACY'],
#       dtype='object')

# %%
feature_list = list(X.columns)

# %%
features = np.array(X)

# %%
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 0.25, random_state = 42)

# %%
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)
# Out:
# Training Features Shape: (725, 99)
# Training Labels Shape: (725,)
# Testing Features Shape: (242, 99)
# Testing Labels Shape: (242,)

# %%
#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel

# %%
clf.fit(train_features, train_labels)
# Out:
# SVC(kernel='linear')

# %%
# Use the forest's predict method on the test data
predictions = clf.predict(test_features)
# Calculate the absolute errors
errors = abs(predictions - test_labels)

# %%
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'score points.')
# Out:
# Mean Absolute Error: 1.4 score points.

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / test_labels)
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
r2 = r2_score(predictions, test_labels)
print('Accuracy:', round(accuracy, 2), '%.')
print('R2 score:', r2)
# Out:
# Accuracy: 65.68 %.
# R2 score: -1.2882403140467655

# %%
# Get numerical feature importances
importances = list(rf.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: TAKWDIST             Importance: 0.03
# Variable: TAWSSIMSPACY         Importance: 0.03
# Variable: TAMIKWWSSIMSPACY     Importance: 0.03
# Variable: TL                   Importance: 0.02
# Variable: TASMEAN              Importance: 0.02
# Variable: TKWAOWRATIO          Importance: 0.02
# Variable: TABSSIMSPACY         Importance: 0.02
# Variable: TAFSSIMSPACY         Importance: 0.02
# Variable: TABSSIMPSPACY        Importance: 0.02
# Variable: TAWSSIMPSPACY        Importance: 0.02
# Variable: TABSSIMBERT          Importance: 0.02
# Variable: TAWSSIMBERT          Importance: 0.02
# Variable: TAFSSIMBERT          Importance: 0.02
# Variable: TAMIKWBSSIMSPACY     Importance: 0.02
# Variable: TAMKWSS              Importance: 0.02
# Variable: TSCC                 Importance: 0.02
# Variable: ASCC                 Importance: 0.02
# Variable: TKWCRATIO            Importance: 0.02
# Variable: TAKWSSIMVARSPACY     Importance: 0.02
# Variable: AL                   Importance: 0.01
# Variable: TWC                  Importance: 0.01
# Variable: ASC                  Importance: 0.01
# Variable: TALRATIO             Importance: 0.01
# Variable: TAWCRATIO            Importance: 0.01
# Variable: AP                   Importance: 0.01
# Variable: TAPD                 Importance: 0.01
# Variable: TAPMEAN              Importance: 0.01
# Variable: AS                   Importance: 0.01
# Variable: TASD                 Importance: 0.01
# Variable: TASCCRATIO           Importance: 0.01
# Variable: TASCCD               Importance: 0.01
# Variable: AFSP                 Importance: 0.01
# Variable: TAFSPMEAN            Importance: 0.01
# Variable: TAFSPD               Importance: 0.01
# Variable: AFSS                 Importance: 0.01
# Variable: TAFSSMEAN            Importance: 0.01
# Variable: TAFSSD               Importance: 0.01
# Variable: TMIKWAORATIO         Importance: 0.01
# Variable: TKWAORATIO           Importance: 0.01
# Variable: TAKWPD               Importance: 0.01
# Variable: AKWPWMEAN            Importance: 0.01
# Variable: TAKWPWMEAN           Importance: 0.01
# Variable: TAKWPWD              Importance: 0.01
# Variable: TAMIKWFP             Importance: 0.01
# Variable: TAMIKWDIST           Importance: 0.01
# Variable: TASIMSPACY           Importance: 0.01
# Variable: TAASSIMSPACY         Importance: 0.01
# Variable: TVC                  Importance: 0.01
# Variable: AVC                  Importance: 0.01
# Variable: TAVCD                Importance: 0.01
# Variable: TNC                  Importance: 0.01
# Variable: ANC                  Importance: 0.01
# Variable: TANCD                Importance: 0.01
# Variable: TAASSIMSBERT         Importance: 0.01
# Variable: TABSSIMPBERT         Importance: 0.01
# Variable: TAWSSIMPBERT         Importance: 0.01
# Variable: TAMIKWASSIMSPACY     Importance: 0.01
# Variable: TAMKWSSIMSPACY       Importance: 0.01
# Variable: TAMKWSP              Importance: 0.01
# Variable: TAMKWSPD             Importance: 0.01
# Variable: TAMKWSSD             Importance: 0.01
# Variable: TAMKWFP              Importance: 0.01
# Variable: TAKWSIMSPACY         Importance: 0.01
# Variable: TAKWSP               Importance: 0.01
# Variable: TAKWSPD              Importance: 0.01
# Variable: TAKWSS               Importance: 0.01
# Variable: TAKWSSD              Importance: 0.01
# Variable: TAGSSIMDISTSPACY     Importance: 0.01
# Variable: TAKWCRATIORATIO      Importance: 0.01
# Variable: TMIKWAO              Importance: 0.01
# Variable: TKWAO                Importance: 0.01
# Variable: TKWAOW               Importance: 0.01
# Variable: TVCRATIO             Importance: 0.01
# Variable: AVCRATIO             Importance: 0.01
# Variable: TAVCRATIOD           Importance: 0.01
# Variable: TNCRATIO             Importance: 0.01
# Variable: ANCRATIO             Importance: 0.01
# Variable: TANCRATIOD           Importance: 0.01
# Variable: AWC                  Importance: 0.0
# Variable: TSC                  Importance: 0.0
# Variable: TASCRATIO            Importance: 0.0
# Variable: TP                   Importance: 0.0
# Variable: TS                   Importance: 0.0
# Variable: TKWC                 Importance: 0.0
# Variable: AKWC                 Importance: 0.0
# Variable: TAKWCRATIO           Importance: 0.0
# Variable: AMIKWP               Importance: 0.0
# Variable: TMIKWS               Importance: 0.0
# Variable: AMIKWS               Importance: 0.0
# Variable: TKWPMEAN             Importance: 0.0
# Variable: AKWPMEAN             Importance: 0.0
# Variable: TAKWPMEAN            Importance: 0.0
# Variable: TKWPWMEAN            Importance: 0.0
# Variable: TAGSSIMRATIOSPACY    Importance: 0.0
# Variable: TAGSSIMRATIOBERT     Importance: 0.0
# Variable: TMIKWP               Importance: 0.0
# Variable: AKWCRATIO            Importance: 0.0
# Variable: TAGSSIMCSPACY        Importance: 0.0
# Variable: TAGSSIMCBERT         Importance: 0.0

# %%
print("Best alpha: %f" % reg.alpha_)
print("Best r2 score: %f" %reg.score(X,y))
coef = pd.Series(reg.coef_, index = X.columns)
print("Lasso picked " + str(sum(coef != 0)) + " features and eliminated the other " +  str(sum(coef == 0)) + " features")
#cross_val_score(reg, X, y, cv=10).mean()
# Out:
# Best alpha: 0.024432
# Best r2 score: 0.042504
# Lasso picked 17 features and eliminated the other 82 features

# %%
imp_coef = coef.sort_values()

# %%
imp_coef
# Out:
# TABSSIMPSPACY      -0.040760
# TAKWDIST           -0.028427
# TMIKWP             -0.012306
# TAMIKWBSSIMSPACY    0.000000
# TAMIKWASSIMSPACY    0.000000
#                       ...
# TAKWCRATIO          0.010203
# TAKWSIMSPACY        0.014752
# TABSSIMBERT         0.018698
# TAWSSIMPSPACY       0.021362
# TAWSSIMSPACY        0.033695
# Length: 99, dtype: float64

# %%
matplotlib.rcParams['figure.figsize'] = (10.0, 15.0)
ax = imp_coef[imp_coef!=0].plot(kind = "barh")
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.patch.set_alpha(0)

ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

ax.spines['left'].set_color('white')
ax.spines['top'].set_color('white')
plt.gcf().subplots_adjust(left=0.25)
fig = ax.get_figure()
fig.savefig('../../images/lasso_features.png', transparent=True)

# %%
imp_coef_abs = coef.abs().sort_values(ascending=False)
imp_coef_abs[imp_coef_abs!=0].keys()
# Out:
# Index(['TABSSIMPSPACY', 'TAWSSIMSPACY', 'TAKWDIST', 'TAWSSIMPSPACY',
#        'TABSSIMBERT', 'TAKWSIMSPACY', 'TMIKWP', 'TAKWCRATIO', 'TKWC',
#        'TABSSIMSPACY', 'TAGSSIMCBERT', 'TAKWSSD', 'TKWAORATIO', 'TAKWSS',
#        'AKWPMEAN', 'TAKWSP', 'TAMIKWWSSIMSPACY'],
#       dtype='object')

# %%
pred = reg.predict(X)

# %%
['CV', 'TL', 'AL', 'TABSIMSPACY', 'TAKWDIST', 'TAWSSIMSPACY', 'TABSIMBERT', 'AMIKWP']
# Out:
# ['CV',
#  'TL',
#  'AL',
#  'TABSIMSPACY',
#  'TAKWDIST',
#  'TAWSSIMSPACY',
#  'TABSIMBERT',
#  'AMIKWP']

# %%
reg.score(X,y)
# Out:
# 0.04250419751862489

# %%
test_labels.shape
# Out:
# (242,)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.scatter(test_labels, predictions,  color='white', alpha=0.3, s=100)
m, b = np.polyfit(test_labels, predictions, 1)
ax.plot(test_labels, m*test_labels+b, color='red', linewidth=3)
ax.plot(test_labels, test_labels, color='green', linewidth=3)
plt.xlabel("Actual")
plt.ylabel("Prediction")

ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')

ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

ax.spines['left'].set_color('white')
ax.spines['top'].set_color('white')

plt.savefig('../../images/logistic_regression.png', transparent=True)

# %%
y_name = 'CV'
features_names = [f'{i}' for i in X.columns]  
column_names = features_names + [y_name]

plot_size=7
num_plots_x=5   # No. of plots in every row
num_plots_y = math.ceil(len(features_names)/num_plots_x)   # No. of plots in y direction

g = sns.FacetGrid(pd.DataFrame(features_names), col=0, col_wrap=5, sharex=False)
for ax, x_var in zip(g.axes, features_names):
    ax.set(ylim=(1, 5))
    sns.regplot(data=df, x=x_var, y=y_name, ax=ax, scatter_kws={"color": "white", "alpha" : 0.1}, line_kws={"color": "red"})
    ax.xaxis.label.set_color('white')
    ax.yaxis.label.set_color('white')

    ax.tick_params(axis='x', colors='white')
    ax.tick_params(axis='y', colors='white')

    ax.spines['left'].set_color('white')
    ax.spines['top'].set_color('white')
g.tight_layout()
fig = g.fig
fig.savefig('../../images/feature_regression.png', transparent=True)

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(projection='3d')

sequence_containing_x_vals = df['TAMIKWWSSIMSPACY']
sequence_containing_y_vals = df['TABSSIMSPACY']
sequence_containing_z_vals = df['CV']

ax.scatter(sequence_containing_x_vals, sequence_containing_y_vals, sequence_containing_z_vals)
plt.show()
